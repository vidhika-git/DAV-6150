# %%
# importing libraries needed
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import probplot
import numpy as np
from pandas.plotting import scatter_matrix

# %%
#loading the data from my own github repo
# Loading Data from Github

# Loading Data from Github

url0 = "https://github.com/vidhika-git/DAV-6150/blob/main/project1/Project1_Data.csv?raw=true"


# Reading Data via pd.read_csv
df = pd.read_csv(url0)

# Displaying first 10 rows of the data
df.head(5)
# Out:
#   report_school_year  aggregation_index aggregation_type  \
# 0            2018-19                  3         District
# 1            2018-19                  3         District
# 2            2018-19                  3         District
# 3            2018-19                  3         District
# 4            2018-19                  3         District
#
#               aggregation_name  nrc_code                   nrc_desc  \
# 0  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 1  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 2  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 3  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 4  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
#
#    county_code county_name  nyc_ind                     membership_desc  ...  \
# 0            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome  ...
# 1            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome  ...
# 2            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome  ...
# 3            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome  ...
# 4            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome  ...
#
#    reg_adv_cnt reg_adv_pct non_diploma_credential_cnt  \
# 0           91         14%                         16
# 1           47         15%                          2
# 2           44         13%                         14
# 3            -           -                          -
# 4           23          6%                         10
#
#   non_diploma_credential_pct still_enr_cnt still_enr_pct ged_cnt ged_pct  \
# 0                         2%            30            5%       0      0%
# 1                         1%            11            3%       0      0%
# 2                         4%            19            6%       0      0%
# 3                          -             -             -       -       -
# 4                         3%            18            5%       0      0%
#
#   dropout_cnt dropout_pct
# 0         148         22%
# 1          65         20%
# 2          83         25%
# 3           -           -
# 4          91         25%
#
# [5 rows x 29 columns]

# %%
df[['enroll_cnt','grad_cnt' ,'grad_pct','local_cnt','local_pct']]
# Out:
#       enroll_cnt grad_cnt grad_pct local_cnt local_pct
# 0            658      464      71%        63       10%
# 1            324      246      76%        30        9%
# 2            334      218      65%        33       10%
# 3              -        -        -         -         -
# 4            367      248      68%        42       11%
# ...          ...      ...      ...       ...       ...
# 73147          -        -        -         -         -
# 73148          -        -        -         -         -
# 73149          -        -        -         -         -
# 73150          -        -        -         -         -
# 73151          -        -        -         -         -
#
# [73152 rows x 5 columns]

# %%
df.shape
# Out:
# (73152, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73152 entries, 0 to 73151
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   report_school_year          73152 non-null  object
#  1   aggregation_index           73152 non-null  int64
#  2   aggregation_type            73152 non-null  object
#  3   aggregation_name            73152 non-null  object
#  4   nrc_code                    73152 non-null  int64
#  5   nrc_desc                    73152 non-null  object
#  6   county_code                 73152 non-null  int64
#  7   county_name                 73152 non-null  object
#  8   nyc_ind                     73152 non-null  int64
#  9   membership_desc             73152 non-null  object
#  10  subgroup_code               73152 non-null  int64
#  11  subgroup_name               73152 non-null  object
#  12  enroll_cnt                  73152 non-null  object
#  13  grad_cnt                    73152 non-null  object
#  14  grad_pct                    73152 non-null  object
#  15  local_cnt                   73152 non-null  object
#  16  local_pct                   73152 non-null  object
#  17  reg_cnt                     73152 non-null  object
#  18  reg_pct                     73152 non-null  object
#  19  reg_adv_cnt                 73152 non-null  object
#  20  reg_adv_pct                 73152 non-null  object
#  21  non_diploma_credential_cnt  73152 non-null  object
#  22  non_diploma_credential_pct  73152 non-null  object
#  23  still_enr_cnt               73152 non-null  object
#  24  still_enr_pct               73152 non-null  object
#  25  ged_cnt                     73152 non-null  object
#  26  ged_pct                     73152 non-null  object
#  27  dropout_cnt                 73152 non-null  object
#  28  dropout_pct                 73152 non-null  object
# dtypes: int64(5), object(24)
# memory usage: 16.2+ MB

# %%
df['dropout_cnt'].value_counts()
# Out:
# 0      7593
# 1      6271
# 2      4296
# 3      3257
# 4      2550
#        ...
# 833       1
# 606       1
# 391       1
# 485       1
# 378       1
# Name: dropout_cnt, Length: 444, dtype: int64

# %%
# Drop rows where the target variable contains '-'
df = df[df['dropout_cnt'] != '-']

# Reset index after dropping rows
df.reset_index(drop=True, inplace=True)

# %%
df[['grad_pct','local_pct','reg_pct','reg_adv_pct','non_diploma_credential_pct','still_enr_pct','ged_pct','dropout_pct']]
# Out:
#       grad_pct local_pct reg_pct reg_adv_pct non_diploma_credential_pct  \
# 0          71%       10%     47%         14%                         2%
# 1          76%        9%     52%         15%                         1%
# 2          65%       10%     42%         13%                         4%
# 3          68%       11%     50%          6%                         3%
# 4          59%       13%     41%          5%                         4%
# ...        ...       ...     ...         ...                        ...
# 39669      69%        6%     56%          8%                         3%
# 39670      90%        6%     67%         17%                         0%
# 39671      15%        0%     15%          0%                        23%
# 39672      70%        0%     61%          9%                         9%
# 39673      79%       11%     50%         18%                         0%
#
#       still_enr_pct ged_pct dropout_pct
# 0                5%      0%         22%
# 1                3%      0%         20%
# 2                6%      0%         25%
# 3                5%      0%         25%
# 4                8%      0%         29%
# ...             ...     ...         ...
# 39669            3%      0%         25%
# 39670            0%      0%         10%
# 39671           15%      0%         46%
# 39672            0%      0%         21%
# 39673            7%      0%         14%
#
# [39674 rows x 8 columns]

# %%
# Box plots
plt.figure(figsize=(12, 8))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

# Assuming df is your DataFrame containing the data
# Replace 'target_variable' with the name of your target variable column
# Replace ['predictor1', 'predictor2', ...] with the names of your predictor variables

# Select relevant columns for correlation analysis
selected_columns = ['grad_pct','local_pct','reg_pct','reg_adv_pct','non_diploma_credential_pct','still_enr_pct','ged_pct', 'enroll_cnt' ,'grad_cnt', 'local_cnt', 'reg_cnt',
    'reg_adv_cnt', 'non_diploma_credential_cnt', 
    'still_enr_cnt',  'ged_cnt','dropout_cnt','dropout_pct']  # Add all predictor variables here
correlation_df = df[selected_columns]

# Calculate correlation matrix
correlation_matrix = correlation_df.corr()

# Extract correlation coefficients with the target variable
target_correlation = correlation_matrix['dropout_cnt'].drop('dropout_cnt')  # Drop target variable from the list

# Sort correlation coefficients by absolute values (optional)
target_correlation = target_correlation.abs().sort_values(ascending=False)

# Print correlation coefficients
print("Correlation coefficients with the target variable:")
print(target_correlation)
# Out:
# Correlation coefficients with the target variable:
# local_cnt                     0.871071
# reg_cnt                       0.851021
# enroll_cnt                    0.846691
# grad_cnt                      0.795895
# ged_cnt                       0.793304
# still_enr_cnt                 0.662578
# non_diploma_credential_cnt    0.584549
# reg_adv_cnt                   0.508226
# dropout_pct                   0.230815
# grad_pct                      0.190834
# reg_adv_pct                   0.184940
# still_enr_pct                 0.085551
# reg_pct                       0.070032
# ged_pct                       0.058422
# non_diploma_credential_pct    0.025518
# local_pct                     0.004871
# Name: dropout_cnt, dtype: float64

# %%
correlation_matrix = correlation_df.corr()
correlation_matrix
# Out:
#                             grad_pct  local_pct   reg_pct  reg_adv_pct  \
# grad_pct                    1.000000  -0.295822  0.269922     0.614538
# local_pct                  -0.295822   1.000000 -0.194961    -0.508401
# reg_pct                     0.269922  -0.194961  1.000000    -0.471707
# reg_adv_pct                 0.614538  -0.508401 -0.471707     1.000000
# non_diploma_credential_pct -0.375972   0.307814 -0.134031    -0.295620
# still_enr_pct              -0.699738   0.150099 -0.222952    -0.379070
# ged_pct                    -0.236343   0.040565 -0.048471    -0.143278
# enroll_cnt                 -0.014102  -0.086368  0.046173    -0.005524
# grad_cnt                    0.034515  -0.106001  0.041879     0.039675
# local_cnt                  -0.145174   0.113220  0.048551    -0.186843
# reg_cnt                    -0.021607  -0.074224  0.139598    -0.085632
# reg_adv_cnt                 0.165698  -0.189537 -0.135157     0.298675
# non_diploma_credential_cnt -0.149882   0.062131  0.021683    -0.146877
# still_enr_cnt              -0.184191  -0.005837  0.029897    -0.145425
# ged_cnt                    -0.121469  -0.020043  0.063255    -0.121083
#
#                             non_diploma_credential_pct  still_enr_pct  \
# grad_pct                                     -0.375972      -0.699738
# local_pct                                     0.307814       0.150099
# reg_pct                                      -0.134031      -0.222952
# reg_adv_pct                                  -0.295620      -0.379070
# non_diploma_credential_pct                    1.000000       0.049829
# still_enr_pct                                 0.049829       1.000000
# ged_pct                                       0.023230       0.068436
# enroll_cnt                                   -0.082267       0.034031
# grad_cnt                                     -0.093745      -0.000300
# local_cnt                                    -0.009024       0.103389
# reg_cnt                                      -0.073567       0.030103
# reg_adv_cnt                                  -0.127803      -0.076961
# non_diploma_credential_cnt                    0.163185       0.040200
# still_enr_cnt                                -0.047223       0.248875
# ged_cnt                                      -0.034955       0.075909
#
#                              ged_pct  enroll_cnt  grad_cnt  local_cnt  \
# grad_pct                   -0.236343   -0.014102  0.034515  -0.145174
# local_pct                   0.040565   -0.086368 -0.106001   0.113220
# reg_pct                    -0.048471    0.046173  0.041879   0.048551
# reg_adv_pct                -0.143278   -0.005524  0.039675  -0.186843
# non_diploma_credential_pct  0.023230   -0.082267 -0.093745  -0.009024
# still_enr_pct               0.068436    0.034031 -0.000300   0.103389
# ged_pct                     1.000000    0.023151  0.011166   0.048194
# enroll_cnt                  0.023151    1.000000  0.993603   0.831018
# grad_cnt                    0.011166    0.993603  1.000000   0.790687
# local_cnt                   0.048194    0.831018  0.790687   1.000000
# reg_cnt                     0.027253    0.979747  0.971027   0.817128
# reg_adv_cnt                -0.027592    0.836960  0.878928   0.520575
# non_diploma_credential_cnt  0.045228    0.511030  0.478744   0.587427
# still_enr_cnt               0.045684    0.762840  0.708722   0.701385
# ged_cnt                     0.211465    0.814510  0.783183   0.767464
#
#                              reg_cnt  reg_adv_cnt  non_diploma_credential_cnt  \
# grad_pct                   -0.021607     0.165698                   -0.149882
# local_pct                  -0.074224    -0.189537                    0.062131
# reg_pct                     0.139598    -0.135157                    0.021683
# reg_adv_pct                -0.085632     0.298675                   -0.146877
# non_diploma_credential_pct -0.073567    -0.127803                    0.163185
# still_enr_pct               0.030103    -0.076961                    0.040200
# ged_pct                     0.027253    -0.027592                    0.045228
# enroll_cnt                  0.979747     0.836960                    0.511030
# grad_cnt                    0.971027     0.878928                    0.478744
# local_cnt                   0.817128     0.520575                    0.587427
# reg_cnt                     1.000000     0.744442                    0.515351
# reg_adv_cnt                 0.744442     1.000000                    0.284526
# non_diploma_credential_cnt  0.515351     0.284526                    1.000000
# still_enr_cnt               0.737750     0.504600                    0.333619
# ged_cnt                     0.820034     0.551338                    0.474265
#
#                             still_enr_cnt   ged_cnt
# grad_pct                        -0.184191 -0.121469
# local_pct                       -0.005837 -0.020043
# reg_pct                          0.029897  0.063255
# reg_adv_pct                     -0.145425 -0.121083
# non_diploma_credential_pct      -0.047223 -0.034955
# still_enr_pct                    0.248875  0.075909
# ged_pct                          0.045684  0.211465
# enroll_cnt                       0.762840  0.814510
# grad_cnt                         0.708722  0.783183
# local_cnt                        0.701385  0.767464
# reg_cnt                          0.737750  0.820034
# reg_adv_cnt                      0.504600  0.551338
# non_diploma_credential_cnt       0.333619  0.474265
# still_enr_cnt                    1.000000  0.674020
# ged_cnt                          0.674020  1.000000

# %%
plt.figure(figsize=(20,20))
plt.title("Correlation Plot")
sns.heatmap(correlation_matrix,annot=True)
plt.show()

# %% [markdown]
# # Example: Predictive imputation using linear regression
# from sklearn.linear_model import LinearRegression
#
# # Select features for prediction
# X = df.dropna(subset=['enroll_cnt'], axis=0).drop(['enroll_cnt',], axis=1)
# y = df.dropna(subset=['enroll_cnt'], axis=0)['enroll_cnt']
#
# # Fit linear regression model
# model = LinearRegression()
# model.fit(X, y)
#
# # Impute missing values using the trained model
# X_missing = df[df['enroll_cnt'].isna()].drop(['enroll_cnt'], axis=1)
# predicted_enroll = model.predict(X_missing)
# df.loc[df['enroll_cnt'].isna(), 'enroll_cnt_imputed'] = predicted_enroll

# %%
# Remove '%' sign and convert to integer
perc=['grad_pct','local_pct','reg_pct','non_diploma_credential_pct','still_enr_pct','ged_pct','dropout_pct','reg_adv_pct']
for col in perc:
    df[col] = df[col].str.rstrip('%').astype(int)

# %%
# Remove '%' sign and convert to integer
perc=['grad_pct','local_pct','reg_pct','non_diploma_credential_pct','still_enr_pct','ged_pct','dropout_pct','reg_adv_pct']
for col in perc:
    df[col] = df[col].str.rstrip('%').astype(int)

# %%
# Columns to convert to numeric
numeric_cols = [
    'enroll_cnt', 'grad_cnt', 'local_cnt', 'reg_cnt',
    'reg_adv_cnt', 'non_diploma_credential_cnt', 
    'still_enr_cnt',  'ged_cnt',  'dropout_cnt', 
]

# Convert object columns to numeric
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
df['nyc_ind'] = df['nyc_ind'].astype(bool)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39674 entries, 0 to 39673
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   report_school_year          39674 non-null  object
#  1   aggregation_index           39674 non-null  int64
#  2   aggregation_type            39674 non-null  object
#  3   aggregation_name            39674 non-null  object
#  4   nrc_code                    39674 non-null  int64
#  5   nrc_desc                    39674 non-null  object
#  6   county_code                 39674 non-null  int64
#  7   county_name                 39674 non-null  object
#  8   nyc_ind                     39674 non-null  bool
#  9   membership_desc             39674 non-null  object
#  10  subgroup_code               39674 non-null  int64
#  11  subgroup_name               39674 non-null  object
#  12  enroll_cnt                  39674 non-null  int64
#  13  grad_cnt                    39674 non-null  int64
#  14  grad_pct                    39674 non-null  int32
#  15  local_cnt                   39674 non-null  int64
#  16  local_pct                   39674 non-null  int32
#  17  reg_cnt                     39674 non-null  int64
#  18  reg_pct                     39674 non-null  int32
#  19  reg_adv_cnt                 39674 non-null  int64
#  20  reg_adv_pct                 39674 non-null  int32
#  21  non_diploma_credential_cnt  39674 non-null  int64
#  22  non_diploma_credential_pct  39674 non-null  int32
#  23  still_enr_cnt               39674 non-null  int64
#  24  still_enr_pct               39674 non-null  int32
#  25  ged_cnt                     39674 non-null  int64
#  26  ged_pct                     39674 non-null  int32
#  27  dropout_cnt                 39674 non-null  int64
#  28  dropout_pct                 39674 non-null  int32
# dtypes: bool(1), int32(8), int64(13), object(7)
# memory usage: 7.3+ MB

# %%
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].value_counts())
    print()
# Out:
# Column: report_school_year
# 2018-19    39674
# Name: report_school_year, dtype: int64
#
# Column: aggregation_index
# 3    39674
# Name: aggregation_index, dtype: int64
#
# Column: aggregation_type
# District    39674
# Name: aggregation_type, dtype: int64
#
# Column: aggregation_name
# SYRACUSE CITY SCHOOL DISTRICT                         116
# NEW YORK CITY GEOGRAPHIC DISTRICT #28                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT #14                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT # 3                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT #31                 108
#                                                      ...
# KIRYAS JOEL VILLAGE UNION FREE SCHOOL DISTRICT          4
# FISHERS ISLAND UNION FREE SCHOOL DISTRICT               4
# LONG LAKE CENTRAL SCHOOL DISTRICT                       2
# GREENBURGH-NORTH CASTLE UNION FREE SCHOOL DISTRICT      2
# BERKSHIRE UNION FREE SCHOOL DISTRICT                    2
# Name: aggregation_name, Length: 677, dtype: int64
#
# Column: nrc_code
# 5    18260
# 6     7136
# 4     7048
# 3     3412
# 1     3382
# 2      436
# Name: nrc_code, dtype: int64
#
# Column: nrc_desc
# Average Needs                            18260
# Low Needs                                 7136
# Rural High Needs                          7048
# Urban-Suburban High Needs                 3412
# NYC                                       3382
# Buffalo  Rochester  Yonkers  Syracuse      436
# Name: nrc_desc, dtype: int64
#
# Column: county_code
# 58    3996
# 28    3152
# 66    2700
# 14    1770
# 26    1356
#       ...
# 67     174
# 35     108
# 68     100
# 55      94
# 20      38
# Name: county_code, Length: 62, dtype: int64
#
# Column: county_name
# SUFFOLK        3996
# NASSAU         3152
# WESTCHESTER    2700
# ERIE           1770
# MONROE         1356
#                ...
# WYOMING         174
# RICHMOND        108
# YATES           100
# SCHUYLER         94
# HAMILTON         38
# Name: county_name, Length: 62, dtype: int64
#
# Column: nyc_ind
# False    36292
# True      3382
# Name: nyc_ind, dtype: int64
#
# Column: membership_desc
# 2015 Total Cohort - 4 Year Outcome                  6676
# 2015 Total Cohort - 4 Year Outcome - August 2019    6676
# 2014 Total Cohort - 5 Year Outcome                  6640
# 2014 Total Cohort - 5 Year Outcome - August 2019    6640
# 2013 Total Cohort - 6 Year Outcome                  6521
# 2013 Total Cohort - 6 Year Outcome - August 2019    6521
# Name: membership_desc, dtype: int64
#
# Column: subgroup_code
# 1     4046
# 3     3970
# 2     3970
# 15    3918
# 16    3918
# 10    3632
# 11    3632
# 8     2790
# 6     1878
# 5     1416
# 7     1122
# 20     962
# 21     962
# 13     872
# 12     872
# 9      708
# 14     572
# 4      270
# 22      36
# 23      36
# 24      28
# 25      28
# 17      18
# 18      18
# Name: subgroup_code, dtype: int64
#
# Column: subgroup_name
# All Students                         4046
# Male                                 3970
# Female                               3970
# Economically Disadvantaged           3918
# Not Economically Disadvantaged       3918
# General Education Students           3632
# Students with Disabilities           3632
# White                                2790
# Hispanic                             1878
# Black                                1416
# Asian/Pacific Islander               1122
# Homeless                              962
# Not Homeless                          962
# English Language Learner              872
# Not English Language Learner          872
# Multiracial                           708
# Formerly English Language Learner     572
# American Indian/Alaska Native         270
# In Foster Care                         36
# Not in Foster Care                     36
# Parent in Armed Forces                 28
# Parent Not in Armed Forces             28
# Migrant                                18
# Not Migrant                            18
# Name: subgroup_name, dtype: int64
#
# Column: enroll_cnt
# 5       802
# 6       664
# 8       656
# 7       654
# 9       584
#        ...
# 1455      2
# 1146      2
# 1224      2
# 1315      2
# 1842      2
# Name: enroll_cnt, Length: 1463, dtype: int64
#
# Column: grad_cnt
# 5       838
# 7       711
# 6       708
# 8       691
# 10      618
#        ...
# 2395      1
# 1093      1
# 2241      1
# 2367      1
# 1571      1
# Name: grad_cnt, Length: 1714, dtype: int64
#
# Column: grad_pct
# 100    3096
# 96     1937
# 95     1917
# 94     1907
# 97     1786
#        ...
# 6         4
# 3         4
# 16        4
# 18        3
# 5         2
# Name: grad_pct, Length: 100, dtype: int64
#
# Column: local_cnt
# 0      6155
# 1      5544
# 2      4288
# 3      3521
# 4      2620
#        ...
# 557       1
# 358       1
# 322       1
# 391       1
# 212       1
# Name: local_cnt, Length: 331, dtype: int64
#
# Column: local_pct
# 0     6510
# 3     3018
# 4     2941
# 5     2763
# 2     2577
#       ...
# 97       2
# 98       2
# 95       2
# 86       2
# 96       2
# Name: local_pct, Length: 80, dtype: int64
#
# Column: reg_cnt
# 3       1270
# 5       1110
# 4       1093
# 2       1047
# 7        935
#         ...
# 4654       1
# 2652       1
# 2002       1
# 1112       1
# 425        1
# Name: reg_cnt, Length: 1289, dtype: int64
#
# Column: reg_pct
# 50    1528
# 44    1210
# 40    1190
# 43    1189
# 38    1140
#       ...
# 84      25
# 87      25
# 2       15
# 3       13
# 1        4
# Name: reg_pct, Length: 101, dtype: int64
#
# Column: reg_adv_cnt
# 0       4471
# 1       1869
# 2       1511
# 3       1297
# 4       1155
#         ...
# 2091       1
# 1079       1
# 412        1
# 931        1
# 1354       1
# Name: reg_adv_cnt, Length: 781, dtype: int64
#
# Column: reg_adv_pct
# 0     4543
# 33     854
# 20     756
# 40     752
# 29     749
#       ...
# 92      29
# 91      21
# 95      10
# 96       6
# 97       6
# Name: reg_adv_pct, Length: 99, dtype: int64
#
# Column: non_diploma_credential_cnt
# 0     21207
# 1      7649
# 2      3863
# 3      1996
# 4      1171
#       ...
# 60        2
# 64        2
# 54        2
# 47        2
# 57        2
# Name: non_diploma_credential_cnt, Length: 75, dtype: int64
#
# Column: non_diploma_credential_pct
# 0     23222
# 1      5763
# 2      3103
# 3      2003
# 4      1198
# 5       895
# 6       608
# 7       482
# 8       461
# 9       249
# 10      225
# 13      211
# 11      184
# 14      176
# 17      153
# 20      129
# 12       90
# 15       72
# 33       54
# 25       50
# 18       47
# 22       42
# 16       33
# 19       30
# 27       24
# 29       20
# 23       20
# 21       19
# 30       18
# 24       12
# 38       12
# 36       10
# 40       10
# 50       10
# 42        6
# 26        5
# 35        4
# 28        4
# 43        4
# 60        4
# 57        2
# 32        2
# 31        2
# 67        2
# 39        2
# 45        2
# Name: non_diploma_credential_pct, dtype: int64
#
# Column: still_enr_cnt
# 0      12473
# 1       6920
# 2       4256
# 3       2806
# 4       1982
#        ...
# 238        1
# 235        1
# 994        1
# 254        1
# 187        1
# Name: still_enr_cnt, Length: 407, dtype: int64
#
# Column: still_enr_pct
# 0     13061
# 1      3881
# 2      3748
# 3      3176
# 4      2435
#       ...
# 87        2
# 98        2
# 75        2
# 51        1
# 83        1
# Name: still_enr_pct, Length: 84, dtype: int64
#
# Column: ged_cnt
# 0     29360
# 1      3770
# 2      1865
# 3       933
# 4       730
#       ...
# 97        2
# 79        2
# 80        2
# 91        2
# 59        2
# Name: ged_cnt, Length: 77, dtype: int64
#
# Column: ged_pct
# 0     30744
# 1      4092
# 2      2068
# 3      1000
# 4       558
# 5       318
# 6       206
# 7       152
# 8       120
# 9        76
# 11       60
# 10       54
# 13       42
# 17       40
# 14       40
# 20       28
# 15       16
# 12       14
# 18       12
# 25        6
# 29        6
# 43        4
# 24        2
# 38        2
# 22        2
# 21        2
# 16        2
# 46        2
# 67        2
# 57        2
# 33        2
# Name: ged_pct, dtype: int64
#
# Column: dropout_cnt
# 0      7593
# 1      6271
# 2      4296
# 3      3257
# 4      2550
#        ...
# 833       1
# 606       1
# 391       1
# 485       1
# 378       1
# Name: dropout_cnt, Length: 444, dtype: int64
#
# Column: dropout_pct
# 0     8127
# 3     2750
# 2     2608
# 1     2580
# 4     2435
#       ...
# 82       2
# 61       2
# 87       2
# 70       2
# 77       2
# Name: dropout_pct, Length: 80, dtype: int64

# %%
df.describe()
# Out:
#        aggregation_index      nrc_code   county_code  subgroup_code  \
# count            39674.0  39674.000000  39674.000000   39674.000000
# mean                 3.0      4.456269     36.774613       8.833795
# std                  0.0      1.367020     20.063556       5.768892
# min                  3.0      1.000000      1.000000       1.000000
# 25%                  3.0      4.000000     21.000000       3.000000
# 50%                  3.0      5.000000     35.000000       9.000000
# 75%                  3.0      5.000000     58.000000      15.000000
# max                  3.0      6.000000     68.000000      25.000000
#
#          enroll_cnt      grad_cnt      grad_pct     local_cnt     local_pct  \
# count  39674.000000  39674.000000  39674.000000  39674.000000  39674.000000
# mean     192.120079    161.178354     84.406614     12.340903      8.479936
# std      439.972474    361.294773     15.679500     32.046302     10.398486
# min        5.000000      0.000000      0.000000      0.000000      0.000000
# 25%       25.000000     20.000000     79.000000      1.000000      2.000000
# 50%       66.000000     57.000000     89.000000      4.000000      6.000000
# 75%      179.000000    156.000000     95.000000     10.000000     11.000000
# max     9176.000000   7540.000000    100.000000    557.000000    100.000000
#
#             reg_cnt  ...   reg_adv_cnt   reg_adv_pct  \
# count  39674.000000  ...  39674.000000  39674.000000
# mean      86.804708  ...     62.032742     32.577204
# std      225.795826  ...    132.777866     23.001197
# min        0.000000  ...      0.000000      0.000000
# 25%       10.000000  ...      4.000000     14.000000
# 50%       27.000000  ...     18.000000     31.000000
# 75%       69.000000  ...     62.000000     49.000000
# max     4752.000000  ...   2231.000000    100.000000
#
#        non_diploma_credential_cnt  non_diploma_credential_pct  still_enr_cnt  \
# count                39674.000000                39674.000000   39674.000000
# mean                     1.924485                    1.742627      11.299516
# std                      6.498913                    4.063987      40.766672
# min                      0.000000                    0.000000       0.000000
# 25%                      0.000000                    0.000000       0.000000
# 50%                      0.000000                    0.000000       2.000000
# 75%                      2.000000                    2.000000       5.000000
# max                    279.000000                   67.000000    1381.000000
#
#        still_enr_pct       ged_cnt       ged_pct   dropout_cnt   dropout_pct
# count   39674.000000  39674.000000  39674.000000  39674.000000  39674.000000
# mean        5.190704      1.377577      0.612693     16.239225      7.963049
# std         8.832710      4.949389      1.985445     50.129834      9.658698
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000      1.000000      1.000000
# 50%         2.000000      0.000000      0.000000      3.000000      5.000000
# 75%         6.000000      1.000000      0.000000      9.000000     11.000000
# max       100.000000     97.000000     67.000000   1091.000000    100.000000
#
# [8 rows x 21 columns]

# %%
variable = 'dropout_cnt'

# Plot histogram using matplotlib
plt.figure(figsize=(10, 6))
plt.hist(df[variable], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Number of Dropouts')
plt.ylabel('Frequency')
plt.title('Histogram of Dropouts')
plt.grid(True)
plt.show()

# %%
df[df.columns].hist(figsize=(15,10), color='pink');

# %%
df.drop(columns=['report_school_year', 'aggregation_index', 'aggregation_type'], inplace=True)

# %%
df.drop(columns=['grad_pct','local_pct','reg_pct','non_diploma_credential_pct','still_enr_pct','ged_pct','dropout_pct','reg_adv_pct'],inplace=True)

# %%
df.head()
# Out:
#               aggregation_name  nrc_code                   nrc_desc  \
# 0  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 1  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 2  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 3  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 4  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
#
#    county_code county_name  nyc_ind                     membership_desc  \
# 0            1      ALBANY    False  2013 Total Cohort - 6 Year Outcome
# 1            1      ALBANY    False  2013 Total Cohort - 6 Year Outcome
# 2            1      ALBANY    False  2013 Total Cohort - 6 Year Outcome
# 3            1      ALBANY    False  2013 Total Cohort - 6 Year Outcome
# 4            1      ALBANY    False  2013 Total Cohort - 6 Year Outcome
#
#    subgroup_code subgroup_name  enroll_cnt  grad_cnt  local_cnt  reg_cnt  \
# 0              1  All Students         658       464         63      310
# 1              2        Female         324       246         30      169
# 2              3          Male         334       218         33      141
# 3              5         Black         367       248         42      183
# 4              6      Hispanic          98        58         13       40
#
#    reg_adv_cnt  non_diploma_credential_cnt  still_enr_cnt  ged_cnt  \
# 0           91                          16             30        0
# 1           47                           2             11        0
# 2           44                          14             19        0
# 3           23                          10             18        0
# 4            5                           4              8        0
#
#    dropout_cnt
# 0          148
# 1           65
# 2           83
# 3           91
# 4           28

# %%
v=df['aggregation_name'].value_counts()

# %%
# Replace 'column_name' with the name of the column you want to analyze
column_name_value_counts = df['aggregation_name'].value_counts()

# Print the unique values a['aggregation_namend their counts
print(column_name_value_counts)
# Out:
# SYRACUSE CITY SCHOOL DISTRICT                         116
# NEW YORK CITY GEOGRAPHIC DISTRICT #28                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT #14                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT # 3                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT #31                 108
#                                                      ...
# KIRYAS JOEL VILLAGE UNION FREE SCHOOL DISTRICT          4
# FISHERS ISLAND UNION FREE SCHOOL DISTRICT               4
# LONG LAKE CENTRAL SCHOOL DISTRICT                       2
# GREENBURGH-NORTH CASTLE UNION FREE SCHOOL DISTRICT      2
# BERKSHIRE UNION FREE SCHOOL DISTRICT                    2
# Name: aggregation_name, Length: 677, dtype: int64

# %%
# Replace 'column_name' with the name of the column you want to analyze
unique_values = df['aggregation_name'].unique()

# Print the unique values
print(unique_values)
# Out:
# ['ALBANY CITY SCHOOL DISTRICT'
#  'BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT'
#  'BETHLEHEM CENTRAL SCHOOL DISTRICT'
#  'RAVENA-COEYMANS-SELKIRK CENTRAL SCHOOL DISTRICT'
#  'COHOES CITY SCHOOL DISTRICT' 'SOUTH COLONIE CENTRAL SCHOOL DISTRICT'
#  'NORTH COLONIE CSD' 'GREEN ISLAND UNION FREE SCHOOL DISTRICT'
#  'GUILDERLAND CENTRAL SCHOOL DISTRICT'
#  'VOORHEESVILLE CENTRAL SCHOOL DISTRICT' 'WATERVLIET CITY SCHOOL DISTRICT'
#  'ALFRED-ALMOND CENTRAL SCHOOL DISTRICT' 'ANDOVER CENTRAL SCHOOL DISTRICT'
#  'GENESEE VALLEY CENTRAL SCHOOL DISTRICT'
#  'BELFAST CENTRAL SCHOOL DISTRICT' 'CANASERAGA CENTRAL SCHOOL DISTRICT'
#  'FRIENDSHIP CENTRAL SCHOOL DISTRICT' 'FILLMORE CENTRAL SCHOOL DISTRICT'
#  'WHITESVILLE CENTRAL SCHOOL DISTRICT'
#  'CUBA-RUSHFORD CENTRAL SCHOOL DISTRICT' 'SCIO CENTRAL SCHOOL DISTRICT'
#  'WELLSVILLE CENTRAL SCHOOL DISTRICT'
#  'BOLIVAR-RICHBURG CENTRAL SCHOOL DISTRICT'
#  'CHENANGO FORKS CENTRAL SCHOOL DISTRICT'
#  'BINGHAMTON CITY SCHOOL DISTRICT' 'HARPURSVILLE CENTRAL SCHOOL DISTRICT'
#  'SUSQUEHANNA VALLEY CENTRAL SCHOOL DISTRICT'
#  'CHENANGO VALLEY CENTRAL SCHOOL DISTRICT'
#  'MAINE-ENDWELL CENTRAL SCHOOL DISTRICT' 'DEPOSIT CENTRAL SCHOOL DISTRICT'
#  'WHITNEY POINT CENTRAL SCHOOL DISTRICT'
#  'UNION-ENDICOTT CENTRAL SCHOOL DISTRICT'
#  'JOHNSON CITY CENTRAL SCHOOL DISTRICT' 'VESTAL CENTRAL SCHOOL DISTRICT'
#  'WINDSOR CENTRAL SCHOOL DISTRICT' 'WEST VALLEY CENTRAL SCHOOL DISTRICT'
#  'ALLEGANY-LIMESTONE CENTRAL SCHOOL DISTRICT'
#  'ELLICOTTVILLE CENTRAL SCHOOL DISTRICT'
#  'FRANKLINVILLE CENTRAL SCHOOL DISTRICT'
#  'HINSDALE CENTRAL SCHOOL DISTRICT'
#  'CATTARAUGUS-LITTLE VALLEY CENTRAL SCHOOL DISTRICT'
#  'OLEAN CITY SCHOOL DISTRICT' 'GOWANDA CENTRAL SCHOOL DISTRICT'
#  'PORTVILLE CENTRAL SCHOOL DISTRICT' 'RANDOLPH CENTRAL SCHOOL DISTRICT'
#  'SALAMANCA CITY SCHOOL DISTRICT'
#  'YORKSHIRE-PIONEER CENTRAL SCHOOL DISTRICT' 'AUBURN CITY SCHOOL DISTRICT'
#  'WEEDSPORT CENTRAL SCHOOL DISTRICT'
#  'CATO-MERIDIAN CENTRAL SCHOOL DISTRICT'
#  'SOUTHERN CAYUGA CENTRAL SCHOOL DISTRICT'
#  'PORT BYRON CENTRAL SCHOOL DISTRICT' 'MORAVIA CENTRAL SCHOOL DISTRICT'
#  'UNION SPRINGS CENTRAL SCHOOL DISTRICT'
#  'SOUTHWESTERN CENTRAL SCHOOL DISTRICT AT JAMESTOWN'
#  'FREWSBURG CENTRAL SCHOOL DISTRICT'
#  'CASSADAGA VALLEY CENTRAL SCHOOL DISTRICT'
#  'CHAUTAUQUA LAKE CENTRAL SCHOOL DISTRICT'
#  'PINE VALLEY CENTRAL SCHOOL DISTRICT (SOUTH DAYTON)'
#  'CLYMER CENTRAL SCHOOL DISTRICT' 'DUNKIRK CITY SCHOOL DISTRICT'
#  'BEMUS POINT CENTRAL SCHOOL DISTRICT' 'FALCONER CENTRAL SCHOOL DISTRICT'
#  'SILVER CREEK CENTRAL SCHOOL DISTRICT'
#  'FORESTVILLE CENTRAL SCHOOL DISTRICT' 'PANAMA CENTRAL SCHOOL DISTRICT'
#  'JAMESTOWN CITY SCHOOL DISTRICT' 'FREDONIA CENTRAL SCHOOL DISTRICT'
#  'BROCTON CENTRAL SCHOOL DISTRICT' 'SHERMAN CENTRAL SCHOOL DISTRICT'
#  'WESTFIELD CENTRAL SCHOOL DISTRICT' 'ELMIRA CITY SCHOOL DISTRICT'
#  'HORSEHEADS CENTRAL SCHOOL DISTRICT'
#  'ELMIRA HEIGHTS CENTRAL SCHOOL DISTRICT' 'AFTON CENTRAL SCHOOL DISTRICT'
#  'BAINBRIDGE-GUILFORD CENTRAL SCHOOL DISTRICT'
#  'GREENE CENTRAL SCHOOL DISTRICT'
#  'UNADILLA VALLEY CENTRAL SCHOOL DISTRICT' 'NORWICH CITY SCHOOL DISTRICT'
#  'GEORGETOWN-SOUTH OTSELIC CENTRAL SCHOOL DISTRICT'
#  'OXFORD ACADEMY AND CENTRAL SCHOOL DISTRICT'
#  'SHERBURNE-EARLVILLE CENTRAL SCHOOL DISTRICT'
#  'AUSABLE VALLEY CENTRAL SCHOOL DISTRICT'
#  'BEEKMANTOWN CENTRAL SCHOOL DISTRICT'
#  'NORTHEASTERN CLINTON CENTRAL SCHOOL DISTRICT'
#  'CHAZY UNION FREE SCHOOL DISTRICT'
#  'NORTHERN ADIRONDACK CENTRAL SCHOOL DISTRICT'
#  'PERU CENTRAL SCHOOL DISTRICT' 'PLATTSBURGH CITY SCHOOL DISTRICT'
#  'SARANAC CENTRAL SCHOOL DISTRICT' 'BERKSHIRE UNION FREE SCHOOL DISTRICT'
#  'TACONIC HILLS CENTRAL SCHOOL DISTRICT'
#  'GERMANTOWN CENTRAL SCHOOL DISTRICT' 'CHATHAM CENTRAL SCHOOL DISTRICT'
#  'HUDSON CITY SCHOOL DISTRICT' 'KINDERHOOK CENTRAL SCHOOL DISTRICT'
#  'NEW LEBANON CENTRAL SCHOOL DISTRICT'
#  'CINCINNATUS CENTRAL SCHOOL DISTRICT' 'CORTLAND CITY SCHOOL DISTRICT'
#  'MCGRAW CENTRAL SCHOOL DISTRICT' 'HOMER CENTRAL SCHOOL DISTRICT'
#  'MARATHON CENTRAL SCHOOL DISTRICT' 'ANDES CENTRAL SCHOOL DISTRICT'
#  'DOWNSVILLE CENTRAL SCHOOL DISTRICT'
#  'CHARLOTTE VALLEY CENTRAL SCHOOL DISTRICT'
#  'DELAWARE ACADEMY CENTRAL SCHOOL DISTRICT AT DELHI'
#  'FRANKLIN CENTRAL SCHOOL DISTRICT' 'HANCOCK CENTRAL SCHOOL DISTRICT'
#  'MARGARETVILLE CENTRAL SCHOOL DISTRICT' 'ROXBURY CENTRAL SCHOOL DISTRICT'
#  'SIDNEY CENTRAL SCHOOL DISTRICT' 'STAMFORD CENTRAL SCHOOL DISTRICT'
#  'SOUTH KORTRIGHT CENTRAL SCHOOL DISTRICT'
#  'WALTON CENTRAL SCHOOL DISTRICT' 'BEACON CITY SCHOOL DISTRICT'
#  'DOVER UNION FREE SCHOOL DISTRICT' 'HYDE PARK CENTRAL SCHOOL DISTRICT'
#  'NORTHEAST CENTRAL SCHOOL DISTRICT' 'PAWLING CENTRAL SCHOOL DISTRICT'
#  'PINE PLAINS CENTRAL SCHOOL DISTRICT' 'POUGHKEEPSIE CITY SCHOOL DISTRICT'
#  'ARLINGTON CENTRAL SCHOOL DISTRICT'
#  'SPACKENKILL UNION FREE SCHOOL DISTRICT'
#  'RED HOOK CENTRAL SCHOOL DISTRICT' 'RHINEBECK CENTRAL SCHOOL DISTRICT'
#  'WAPPINGERS CENTRAL SCHOOL DISTRICT' 'MILLBROOK CENTRAL SCHOOL DISTRICT'
#  'ALDEN CENTRAL SCHOOL DISTRICT' 'AMHERST CENTRAL SCHOOL DISTRICT'
#  'WILLIAMSVILLE CENTRAL SCHOOL DISTRICT'
#  'SWEET HOME CENTRAL SCHOOL DISTRICT'
#  'EAST AURORA UNION FREE SCHOOL DISTRICT' 'BUFFALO CITY SCHOOL DISTRICT'
#  'CHEEKTOWAGA CENTRAL SCHOOL DISTRICT'
#  'CHEEKTOWAGA-MARYVALE UNION FREE SCHOOL DISTRICT'
#  'CLEVELAND HILL UNION FREE SCHOOL DISTRICT'
#  'DEPEW UNION FREE SCHOOL DISTRICT'
#  'CHEEKTOWAGA-SLOAN UNION FREE SCHOOL DISTRICT'
#  'CLARENCE CENTRAL SCHOOL DISTRICT'
#  'SPRINGVILLE-GRIFFITH INSTITUTE CENTRAL SCHOOL DISTRICT'
#  'EDEN CENTRAL SCHOOL DISTRICT' 'IROQUOIS CENTRAL SCHOOL DISTRICT'
#  'EVANS-BRANT CENTRAL SCHOOL DISTRICT (LAKE SHORE)'
#  'GRAND ISLAND CENTRAL SCHOOL DISTRICT' 'HAMBURG CENTRAL SCHOOL DISTRICT'
#  'FRONTIER CENTRAL SCHOOL DISTRICT' 'HOLLAND CENTRAL SCHOOL DISTRICT'
#  'LACKAWANNA CITY SCHOOL DISTRICT' 'LANCASTER CENTRAL SCHOOL DISTRICT'
#  'AKRON CENTRAL SCHOOL DISTRICT' 'NORTH COLLINS CENTRAL SCHOOL DISTRICT'
#  'ORCHARD PARK CENTRAL SCHOOL DISTRICT' 'TONAWANDA CITY SCHOOL DISTRICT'
#  'KENMORE-TONAWANDA UNION FREE SCHOOL DISTRICT'
#  'WEST SENECA CENTRAL SCHOOL DISTRICT'
#  'CROWN POINT CENTRAL SCHOOL DISTRICT'
#  'ELIZABETHTOWN-LEWIS CENTRAL SCHOOL DISTRICT'
#  'KEENE CENTRAL SCHOOL DISTRICT' 'MINERVA CENTRAL SCHOOL DISTRICT'
#  'MORIAH CENTRAL SCHOOL DISTRICT' 'NEWCOMB CENTRAL SCHOOL DISTRICT'
#  'LAKE PLACID CENTRAL SCHOOL DISTRICT'
#  'SCHROON LAKE CENTRAL SCHOOL DISTRICT'
#  'TICONDEROGA CENTRAL SCHOOL DISTRICT' 'WESTPORT CENTRAL SCHOOL DISTRICT'
#  'WILLSBORO CENTRAL SCHOOL DISTRICT' 'TUPPER LAKE CENTRAL SCHOOL DISTRICT'
#  'CHATEAUGAY CENTRAL SCHOOL DISTRICT'
#  'SALMON RIVER CENTRAL SCHOOL DISTRICT'
#  'SARANAC LAKE CENTRAL SCHOOL DISTRICT' 'MALONE CENTRAL SCHOOL DISTRICT'
#  'BRUSHTON-MOIRA CENTRAL SCHOOL DISTRICT'
#  'SAINT REGIS FALLS CENTRAL SCHOOL DISTRICT'
#  'GLOVERSVILLE CITY SCHOOL DISTRICT' 'JOHNSTOWN CITY SCHOOL DISTRICT'
#  'MAYFIELD CENTRAL SCHOOL DISTRICT' 'NORTHVILLE CENTRAL SCHOOL DISTRICT'
#  'BROADALBIN-PERTH CENTRAL SCHOOL DISTRICT'
#  'ALEXANDER CENTRAL SCHOOL DISTRICT' 'BATAVIA CITY SCHOOL DISTRICT'
#  'BYRON-BERGEN CENTRAL SCHOOL DISTRICT' 'ELBA CENTRAL SCHOOL DISTRICT'
#  'LE ROY CENTRAL SCHOOL DISTRICT'
#  'OAKFIELD-ALABAMA CENTRAL SCHOOL DISTRICT'
#  'PAVILION CENTRAL SCHOOL DISTRICT' 'PEMBROKE CENTRAL SCHOOL DISTRICT'
#  'CAIRO-DURHAM CENTRAL SCHOOL DISTRICT' 'CATSKILL CENTRAL SCHOOL DISTRICT'
#  'COXSACKIE-ATHENS CENTRAL SCHOOL DISTRICT'
#  'GREENVILLE CENTRAL SCHOOL DISTRICT'
#  'HUNTER-TANNERSVILLE CENTRAL SCHOOL DISTRICT'
#  'WINDHAM-ASHLAND-JEWETT CENTRAL SCHOOL DISTRICT'
#  'INDIAN LAKE CENTRAL SCHOOL DISTRICT' 'LONG LAKE CENTRAL SCHOOL DISTRICT'
#  'WELLS CENTRAL SCHOOL DISTRICT'
#  'WEST CANADA VALLEY CENTRAL SCHOOL DISTRICT'
#  'FRANKFORT-SCHUYLER CENTRAL SCHOOL DISTRICT'
#  'HERKIMER CENTRAL SCHOOL DISTRICT' 'LITTLE FALLS CITY SCHOOL DISTRICT'
#  'DOLGEVILLE CENTRAL SCHOOL DISTRICT' 'POLAND CENTRAL SCHOOL DISTRICT'
#  'VAN HORNESVILLE-OWEN D YOUNG CENTRAL SCHOOL DISTRICT'
#  'TOWN OF WEBB UNION FREE SCHOOL DISTRICT'
#  'MOUNT MARKHAM CENTRAL SCHOOL DISTRICT'
#  'CENTRAL VALLEY CSD AT ILION-MOHAWK'
#  'SOUTH JEFFERSON CENTRAL SCHOOL DISTRICT'
#  'ALEXANDRIA CENTRAL SCHOOL DISTRICT'
#  'INDIAN RIVER CENTRAL SCHOOL DISTRICT'
#  'GENERAL BROWN CENTRAL SCHOOL DISTRICT'
#  'THOUSAND ISLANDS CENTRAL SCHOOL DISTRICT'
#  'BELLEVILLE-HENDERSON CENTRAL SCHOOL DISTRICT'
#  'SACKETS HARBOR CENTRAL SCHOOL DISTRICT' 'LYME CENTRAL SCHOOL DISTRICT'
#  'LA FARGEVILLE CENTRAL SCHOOL DISTRICT' 'WATERTOWN CITY SCHOOL DISTRICT'
#  'CARTHAGE CENTRAL SCHOOL DISTRICT' 'COPENHAGEN CENTRAL SCHOOL DISTRICT'
#  'HARRISVILLE CENTRAL SCHOOL DISTRICT'
#  'LOWVILLE ACADEMY & CENTRAL SCHOOL DISTRICT'
#  'SOUTH LEWIS CENTRAL SCHOOL DISTRICT'
#  'BEAVER RIVER CENTRAL SCHOOL DISTRICT' 'AVON CENTRAL SCHOOL DISTRICT'
#  'CALEDONIA-MUMFORD CENTRAL SCHOOL DISTRICT'
#  'GENESEO CENTRAL SCHOOL DISTRICT' 'LIVONIA CENTRAL SCHOOL DISTRICT'
#  'MOUNT MORRIS CENTRAL SCHOOL DISTRICT'
#  'DANSVILLE CENTRAL SCHOOL DISTRICT'
#  'DALTON-NUNDA CENTRAL SCHOOL DISTRICT (KESHEQUA)'
#  'YORK CENTRAL SCHOOL DISTRICT' 'BROOKFIELD CENTRAL SCHOOL DISTRICT'
#  'CAZENOVIA CENTRAL SCHOOL DISTRICT' 'DERUYTER CENTRAL SCHOOL DISTRICT'
#  'MORRISVILLE-EATON CENTRAL SCHOOL DISTRICT'
#  'HAMILTON CENTRAL SCHOOL DISTRICT' 'CANASTOTA CENTRAL SCHOOL DISTRICT'
#  'MADISON CENTRAL SCHOOL DISTRICT' 'ONEIDA CITY SCHOOL DISTRICT'
#  'STOCKBRIDGE VALLEY CENTRAL SCHOOL DISTRICT'
#  'CHITTENANGO CENTRAL SCHOOL DISTRICT' 'BRIGHTON CENTRAL SCHOOL DISTRICT'
#  'GATES-CHILI CENTRAL SCHOOL DISTRICT' 'GREECE CENTRAL SCHOOL DISTRICT'
#  'EAST IRONDEQUOIT CENTRAL SCHOOL DISTRICT'
#  'WEST IRONDEQUOIT CENTRAL SCHOOL DISTRICT'
#  'HONEOYE FALLS-LIMA CENTRAL SCHOOL DISTRICT'
#  'SPENCERPORT CENTRAL SCHOOL DISTRICT' 'HILTON CENTRAL SCHOOL DISTRICT'
#  'PENFIELD CENTRAL SCHOOL DISTRICT' 'FAIRPORT CENTRAL SCHOOL DISTRICT'
#  'EAST ROCHESTER UNION FREE SCHOOL DISTRICT'
#  'PITTSFORD CENTRAL SCHOOL DISTRICT'
#  'CHURCHVILLE-CHILI CENTRAL SCHOOL DISTRICT'
#  'ROCHESTER CITY SCHOOL DISTRICT' 'RUSH-HENRIETTA CENTRAL SCHOOL DISTRICT'
#  'BROCKPORT CENTRAL SCHOOL DISTRICT' 'WEBSTER CENTRAL SCHOOL DISTRICT'
#  'WHEATLAND-CHILI CENTRAL SCHOOL DISTRICT'
#  'AMSTERDAM CITY SCHOOL DISTRICT' 'CANAJOHARIE CENTRAL SCHOOL DISTRICT'
#  'FONDA-FULTONVILLE CENTRAL SCHOOL DISTRICT'
#  'FORT PLAIN CENTRAL SCHOOL DISTRICT'
#  'OPPENHEIM-EPHRATAH-ST. JOHNSVILLE CSD' 'GLEN COVE CITY SCHOOL DISTRICT'
#  'HEMPSTEAD UNION FREE SCHOOL DISTRICT'
#  'UNIONDALE UNION FREE SCHOOL DISTRICT'
#  'EAST MEADOW UNION FREE SCHOOL DISTRICT'
#  'LEVITTOWN UNION FREE SCHOOL DISTRICT'
#  'SEAFORD UNION FREE SCHOOL DISTRICT'
#  'ROOSEVELT UNION FREE SCHOOL DISTRICT'
#  'FREEPORT UNION FREE SCHOOL DISTRICT'
#  'BALDWIN UNION FREE SCHOOL DISTRICT'
#  'OCEANSIDE UNION FREE SCHOOL DISTRICT'
#  'MALVERNE UNION FREE SCHOOL DISTRICT'
#  'HEWLETT-WOODMERE UNION FREE SCHOOL DISTRICT'
#  'LAWRENCE UNION FREE SCHOOL DISTRICT'
#  'GARDEN CITY UNION FREE SCHOOL DISTRICT'
#  'EAST ROCKAWAY UNION FREE SCHOOL DISTRICT'
#  'LYNBROOK UNION FREE SCHOOL DISTRICT'
#  'ROCKVILLE CENTRE UNION FREE SCHOOL DISTRICT'
#  'WANTAGH UNION FREE SCHOOL DISTRICT'
#  'ISLAND TREES UNION FREE SCHOOL DISTRICT'
#  'WEST HEMPSTEAD UNION FREE SCHOOL DISTRICT'
#  'VALLEY STREAM CENTRAL HIGH SCHOOL DISTRICT'
#  'SEWANHAKA CENTRAL HIGH SCHOOL DISTRICT'
#  'BELLMORE-MERRICK CENTRAL HIGH SCHOOL DISTRICT'
#  'LONG BEACH CITY SCHOOL DISTRICT' 'WESTBURY UNION FREE SCHOOL DISTRICT'
#  'EAST WILLISTON UNION FREE SCHOOL DISTRICT'
#  'ROSLYN UNION FREE SCHOOL DISTRICT'
#  'PORT WASHINGTON UNION FREE SCHOOL DISTRICT'
#  'MANHASSET UNION FREE SCHOOL DISTRICT'
#  'GREAT NECK UNION FREE SCHOOL DISTRICT'
#  'HERRICKS UNION FREE SCHOOL DISTRICT'
#  'MINEOLA UNION FREE SCHOOL DISTRICT'
#  'CARLE PLACE UNION FREE SCHOOL DISTRICT'
#  'NORTH SHORE CENTRAL SCHOOL DISTRICT' 'SYOSSET CENTRAL SCHOOL DISTRICT'
#  'LOCUST VALLEY CENTRAL SCHOOL DISTRICT'
#  'PLAINVIEW-OLD BETHPAGE CENTRAL SCHOOL DISTRICT'
#  'OYSTER BAY-EAST NORWICH CENTRAL SCHOOL DISTRICT'
#  'JERICHO UNION FREE SCHOOL DISTRICT'
#  'HICKSVILLE UNION FREE SCHOOL DISTRICT'
#  'PLAINEDGE UNION FREE SCHOOL DISTRICT'
#  'BETHPAGE UNION FREE SCHOOL DISTRICT'
#  'FARMINGDALE UNION FREE SCHOOL DISTRICT'
#  'MASSAPEQUA UNION FREE SCHOOL DISTRICT'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 1'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 2'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 3'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 4'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 5'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 6'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 7'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 8'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT # 9'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #10'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #11'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #12'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #13'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #14'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #15'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #16'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #17'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #18'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #19'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #20'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #21'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #22'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #23'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #32'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #24'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #25'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #26'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #27'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #28'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #29'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #30'
#  'NEW YORK CITY GEOGRAPHIC DISTRICT #31'
#  'LEWISTON-PORTER CENTRAL SCHOOL DISTRICT' 'LOCKPORT CITY SCHOOL DISTRICT'
#  'NEWFANE CENTRAL SCHOOL DISTRICT'
#  'NIAGARA-WHEATFIELD CENTRAL SCHOOL DISTRICT'
#  'NIAGARA FALLS CITY SCHOOL DISTRICT'
#  'NORTH TONAWANDA CITY SCHOOL DISTRICT'
#  'STARPOINT CENTRAL SCHOOL DISTRICT'
#  'ROYALTON-HARTLAND CENTRAL SCHOOL DISTRICT'
#  'BARKER CENTRAL SCHOOL DISTRICT' 'WILSON CENTRAL SCHOOL DISTRICT'
#  'ADIRONDACK CENTRAL SCHOOL DISTRICT' 'CAMDEN CENTRAL SCHOOL DISTRICT'
#  'CLINTON CENTRAL SCHOOL DISTRICT' 'NEW HARTFORD CENTRAL SCHOOL DISTRICT'
#  'NEW YORK MILLS UNION FREE SCHOOL DISTRICT'
#  'SAUQUOIT VALLEY CENTRAL SCHOOL DISTRICT'
#  'REMSEN CENTRAL SCHOOL DISTRICT' 'ROME CITY SCHOOL DISTRICT'
#  'WATERVILLE CENTRAL SCHOOL DISTRICT' 'SHERRILL CITY SCHOOL DISTRICT'
#  'HOLLAND PATENT CENTRAL SCHOOL DISTRICT' 'UTICA CITY SCHOOL DISTRICT'
#  'WESTMORELAND CENTRAL SCHOOL DISTRICT' 'ORISKANY CENTRAL SCHOOL DISTRICT'
#  'WHITESBORO CENTRAL SCHOOL DISTRICT'
#  'WEST GENESEE CENTRAL SCHOOL DISTRICT'
#  'NORTH SYRACUSE CENTRAL SCHOOL DISTRICT'
#  'EAST SYRACUSE MINOA CENTRAL SCHOOL DISTRICT'
#  'JAMESVILLE-DEWITT CENTRAL SCHOOL DISTRICT'
#  'JORDAN-ELBRIDGE CENTRAL SCHOOL DISTRICT'
#  'FABIUS-POMPEY CENTRAL SCHOOL DISTRICT'
#  'WESTHILL CENTRAL SCHOOL DISTRICT' 'SOLVAY UNION FREE SCHOOL DISTRICT'
#  'LAFAYETTE CENTRAL SCHOOL DISTRICT'
#  'BALDWINSVILLE CENTRAL SCHOOL DISTRICT'
#  'FAYETTEVILLE-MANLIUS CENTRAL SCHOOL DISTRICT'
#  'MARCELLUS CENTRAL SCHOOL DISTRICT' 'ONONDAGA CENTRAL SCHOOL DISTRICT'
#  'LIVERPOOL CENTRAL SCHOOL DISTRICT' 'SKANEATELES CENTRAL SCHOOL DISTRICT'
#  'SYRACUSE CITY SCHOOL DISTRICT' 'TULLY CENTRAL SCHOOL DISTRICT'
#  'CANANDAIGUA CITY SCHOOL DISTRICT'
#  'EAST BLOOMFIELD CENTRAL SCHOOL DISTRICT' 'GENEVA CITY SCHOOL DISTRICT'
#  'GORHAM-MIDDLESEX CENTRAL SCHOOL DISTRICT (MARCUS WHITMAN)'
#  'MANCHESTER-SHORTSVILLE CENTRAL SCHOOL DISTRICT (RED JACKET)'
#  'NAPLES CENTRAL SCHOOL DISTRICT'
#  'PHELPS-CLIFTON SPRINGS CENTRAL SCHOOL DISTRICT'
#  'HONEOYE CENTRAL SCHOOL DISTRICT' 'VICTOR CENTRAL SCHOOL DISTRICT'
#  'WASHINGTONVILLE CENTRAL SCHOOL DISTRICT'
#  'CHESTER UNION FREE SCHOOL DISTRICT' 'CORNWALL CENTRAL SCHOOL DISTRICT'
#  'PINE BUSH CENTRAL SCHOOL DISTRICT' 'GOSHEN CENTRAL SCHOOL DISTRICT'
#  'HIGHLAND FALLS CENTRAL SCHOOL DISTRICT'
#  'MIDDLETOWN CITY SCHOOL DISTRICT'
#  'MINISINK VALLEY CENTRAL SCHOOL DISTRICT'
#  'MONROE-WOODBURY CENTRAL SCHOOL DISTRICT'
#  'KIRYAS JOEL VILLAGE UNION FREE SCHOOL DISTRICT'
#  'VALLEY CENTRAL SCHOOL DISTRICT (MONTGOMERY)'
#  'NEWBURGH CITY SCHOOL DISTRICT' 'PORT JERVIS CITY SCHOOL DISTRICT'
#  'TUXEDO UNION FREE SCHOOL DISTRICT'
#  'WARWICK VALLEY CENTRAL SCHOOL DISTRICT'
#  'FLORIDA UNION FREE SCHOOL DISTRICT' 'ALBION CENTRAL SCHOOL DISTRICT'
#  'KENDALL CENTRAL SCHOOL DISTRICT' 'HOLLEY CENTRAL SCHOOL DISTRICT'
#  'MEDINA CENTRAL SCHOOL DISTRICT' 'LYNDONVILLE CENTRAL SCHOOL DISTRICT'
#  'ALTMAR-PARISH-WILLIAMSTOWN CENTRAL SCHOOL DISTRICT'
#  'FULTON CITY SCHOOL DISTRICT' 'HANNIBAL CENTRAL SCHOOL DISTRICT'
#  'CENTRAL SQUARE CENTRAL SCHOOL DISTRICT' 'MEXICO CENTRAL SCHOOL DISTRICT'
#  'OSWEGO CITY SCHOOL DISTRICT' 'PULASKI CENTRAL SCHOOL DISTRICT'
#  'SANDY CREEK CENTRAL SCHOOL DISTRICT' 'PHOENIX CENTRAL SCHOOL DISTRICT'
#  'GILBERTSVILLE-MOUNT UPTON CENTRAL SCHOOL DISTRICT'
#  'EDMESTON CENTRAL SCHOOL DISTRICT' 'LAURENS CENTRAL SCHOOL DISTRICT'
#  'SCHENEVUS CENTRAL SCHOOL DISTRICT' 'MILFORD CENTRAL SCHOOL DISTRICT'
#  'MORRIS CENTRAL SCHOOL DISTRICT' 'ONEONTA CITY SCHOOL DISTRICT'
#  'OTEGO-UNADILLA CENTRAL SCHOOL DISTRICT'
#  'COOPERSTOWN CENTRAL SCHOOL DISTRICT'
#  'RICHFIELD SPRINGS CENTRAL SCHOOL DISTRICT'
#  'CHERRY VALLEY-SPRINGFIELD CENTRAL SCHOOL DISTRICT'
#  'WORCESTER CENTRAL SCHOOL DISTRICT' 'MAHOPAC CENTRAL SCHOOL DISTRICT'
#  'CARMEL CENTRAL SCHOOL DISTRICT' 'HALDANE CENTRAL SCHOOL DISTRICT'
#  'PUTNAM VALLEY CENTRAL SCHOOL DISTRICT'
#  'BREWSTER CENTRAL SCHOOL DISTRICT' 'BERLIN CENTRAL SCHOOL DISTRICT'
#  'BRUNSWICK CENTRAL SCHOOL DISTRICT (BRITTONKILL)'
#  'EAST GREENBUSH CENTRAL SCHOOL DISTRICT'
#  'HOOSICK FALLS CENTRAL SCHOOL DISTRICT'
#  'LANSINGBURGH CENTRAL SCHOOL DISTRICT' 'RENSSELAER CITY SCHOOL DISTRICT'
#  'AVERILL PARK CENTRAL SCHOOL DISTRICT'
#  'HOOSIC VALLEY CENTRAL SCHOOL DISTRICT'
#  'SCHODACK CENTRAL SCHOOL DISTRICT' 'TROY CITY SCHOOL DISTRICT'
#  'CLARKSTOWN CENTRAL SCHOOL DISTRICT' 'NANUET UNION FREE SCHOOL DISTRICT'
#  'HAVERSTRAW-STONY POINT CSD (NORTH ROCKLAND)'
#  'SOUTH ORANGETOWN CENTRAL SCHOOL DISTRICT'
#  'NYACK UNION FREE SCHOOL DISTRICT'
#  'PEARL RIVER UNION FREE SCHOOL DISTRICT'
#  'SUFFERN CENTRAL SCHOOL DISTRICT'
#  'EAST RAMAPO CENTRAL SCHOOL DISTRICT (SPRING VALLEY)'
#  'BRASHER FALLS CENTRAL SCHOOL DISTRICT' 'CANTON CENTRAL SCHOOL DISTRICT'
#  'CLIFTON-FINE CENTRAL SCHOOL DISTRICT'
#  'COLTON-PIERREPONT CENTRAL SCHOOL DISTRICT'
#  'GOUVERNEUR CENTRAL SCHOOL DISTRICT' 'HAMMOND CENTRAL SCHOOL DISTRICT'
#  'HERMON-DEKALB CENTRAL SCHOOL DISTRICT' 'LISBON CENTRAL SCHOOL DISTRICT'
#  'MADRID-WADDINGTON CENTRAL SCHOOL DISTRICT'
#  'MASSENA CENTRAL SCHOOL DISTRICT' 'MORRISTOWN CENTRAL SCHOOL DISTRICT'
#  'NORWOOD-NORFOLK CENTRAL SCHOOL DISTRICT'
#  'OGDENSBURG CITY SCHOOL DISTRICT' 'HEUVELTON CENTRAL SCHOOL DISTRICT'
#  'PARISHVILLE-HOPKINTON CENTRAL SCHOOL DISTRICT'
#  'POTSDAM CENTRAL SCHOOL DISTRICT' 'EDWARDS-KNOX CENTRAL SCHOOL DISTRICT'
#  'BURNT HILLS-BALLSTON LAKE CENTRAL SCHOOL DISTRICT'
#  'SHENENDEHOWA CENTRAL SCHOOL DISTRICT' 'CORINTH CENTRAL SCHOOL DISTRICT'
#  'GALWAY CENTRAL SCHOOL DISTRICT' 'MECHANICVILLE CITY SCHOOL DISTRICT'
#  'BALLSTON SPA CENTRAL SCHOOL DISTRICT'
#  'SOUTH GLENS FALLS CENTRAL SCHOOL DISTRICT'
#  'SCHUYLERVILLE CENTRAL SCHOOL DISTRICT'
#  'THE ENLARGED CITY SCHOOL DISTRICT OF THE CITY OF SARATOGA SP'
#  'STILLWATER CENTRAL SCHOOL DISTRICT'
#  'WATERFORD-HALFMOON UNION FREE SCHOOL DISTRICT'
#  'DUANESBURG CENTRAL SCHOOL DISTRICT'
#  'SCOTIA-GLENVILLE CENTRAL SCHOOL DISTRICT'
#  'NISKAYUNA CENTRAL SCHOOL DISTRICT' 'SCHALMONT CENTRAL SCHOOL DISTRICT'
#  'ROTTERDAM-MOHONASEN CENTRAL SCHOOL DISTRICT'
#  'SCHENECTADY CITY SCHOOL DISTRICT'
#  'GILBOA-CONESVILLE CENTRAL SCHOOL DISTRICT'
#  'JEFFERSON CENTRAL SCHOOL DISTRICT' 'MIDDLEBURGH CENTRAL SCHOOL DISTRICT'
#  'COBLESKILL-RICHMONDVILLE CENTRAL SCHOOL DISTRICT'
#  'SCHOHARIE CENTRAL SCHOOL DISTRICT'
#  'SHARON SPRINGS CENTRAL SCHOOL DISTRICT'
#  'ODESSA-MONTOUR CENTRAL SCHOOL DISTRICT'
#  'WATKINS GLEN CENTRAL SCHOOL DISTRICT'
#  'SOUTH SENECA CENTRAL SCHOOL DISTRICT' 'ROMULUS CENTRAL SCHOOL DISTRICT'
#  'SENECA FALLS CENTRAL SCHOOL DISTRICT' 'WATERLOO CENTRAL SCHOOL DISTRICT'
#  'ADDISON CENTRAL SCHOOL DISTRICT' 'AVOCA CENTRAL SCHOOL DISTRICT'
#  'BATH CENTRAL SCHOOL DISTRICT' 'BRADFORD CENTRAL SCHOOL DISTRICT'
#  'CAMPBELL-SAVONA CENTRAL SCHOOL DISTRICT' 'CORNING CITY SCHOOL DISTRICT'
#  'CANISTEO-GREENWOOD CSD' 'HORNELL CITY SCHOOL DISTRICT'
#  'ARKPORT CENTRAL SCHOOL DISTRICT' 'PRATTSBURGH CENTRAL SCHOOL DISTRICT'
#  'JASPER-TROUPSBURG CENTRAL SCHOOL DISTRICT'
#  'HAMMONDSPORT CENTRAL SCHOOL DISTRICT'
#  'WAYLAND-COHOCTON CENTRAL SCHOOL DISTRICT'
#  'BABYLON UNION FREE SCHOOL DISTRICT'
#  'WEST BABYLON UNION FREE SCHOOL DISTRICT'
#  'NORTH BABYLON UNION FREE SCHOOL DISTRICT'
#  'LINDENHURST UNION FREE SCHOOL DISTRICT'
#  'COPIAGUE UNION FREE SCHOOL DISTRICT'
#  'AMITYVILLE UNION FREE SCHOOL DISTRICT'
#  'DEER PARK UNION FREE SCHOOL DISTRICT'
#  'WYANDANCH UNION FREE SCHOOL DISTRICT'
#  'THREE VILLAGE CENTRAL SCHOOL DISTRICT'
#  'BROOKHAVEN-COMSEWOGUE UNION FREE SCHOOL DISTRICT'
#  'SACHEM CENTRAL SCHOOL DISTRICT'
#  'PORT JEFFERSON UNION FREE SCHOOL DISTRICT'
#  'MOUNT SINAI UNION FREE SCHOOL DISTRICT'
#  'MILLER PLACE UNION FREE SCHOOL DISTRICT'
#  'ROCKY POINT UNION FREE SCHOOL DISTRICT'
#  'MIDDLE COUNTRY CENTRAL SCHOOL DISTRICT'
#  'LONGWOOD CENTRAL SCHOOL DISTRICT'
#  'PATCHOGUE-MEDFORD UNION FREE SCHOOL DISTRICT'
#  'WILLIAM FLOYD UNION FREE SCHOOL DISTRICT'
#  'CENTER MORICHES UNION FREE SCHOOL DISTRICT'
#  'SOUTH COUNTRY CENTRAL SCHOOL DISTRICT'
#  'EAST HAMPTON UNION FREE SCHOOL DISTRICT'
#  'SAG HARBOR UNION FREE SCHOOL DISTRICT'
#  'ELWOOD UNION FREE SCHOOL DISTRICT'
#  'COLD SPRING HARBOR CENTRAL SCHOOL DISTRICT'
#  'HUNTINGTON UNION FREE SCHOOL DISTRICT'
#  'NORTHPORT-EAST NORTHPORT UNION FREE SCHOOL DISTRICT'
#  'HALF HOLLOW HILLS CENTRAL SCHOOL DISTRICT'
#  'HARBORFIELDS CENTRAL SCHOOL DISTRICT'
#  'COMMACK UNION FREE SCHOOL DISTRICT'
#  'SOUTH HUNTINGTON UNION FREE SCHOOL DISTRICT'
#  'BAY SHORE UNION FREE SCHOOL DISTRICT' 'ISLIP UNION FREE SCHOOL DISTRICT'
#  'EAST ISLIP UNION FREE SCHOOL DISTRICT'
#  'SAYVILLE UNION FREE SCHOOL DISTRICT'
#  'BAYPORT-BLUE POINT UNION FREE SCHOOL DISTRICT'
#  'HAUPPAUGE UNION FREE SCHOOL DISTRICT'
#  'CONNETQUOT CENTRAL SCHOOL DISTRICT'
#  'WEST ISLIP UNION FREE SCHOOL DISTRICT'
#  'BRENTWOOD UNION FREE SCHOOL DISTRICT'
#  'CENTRAL ISLIP UNION FREE SCHOOL DISTRICT'
#  'SHOREHAM-WADING RIVER CENTRAL SCHOOL DISTRICT'
#  'RIVERHEAD CENTRAL SCHOOL DISTRICT'
#  'SHELTER ISLAND UNION FREE SCHOOL DISTRICT'
#  'SMITHTOWN CENTRAL SCHOOL DISTRICT' 'KINGS PARK CENTRAL SCHOOL DISTRICT'
#  'WESTHAMPTON BEACH UNION FREE SCHOOL DISTRICT'
#  'HAMPTON BAYS UNION FREE SCHOOL DISTRICT'
#  'SOUTHAMPTON UNION FREE SCHOOL DISTRICT'
#  'BRIDGEHAMPTON UNION FREE SCHOOL DISTRICT' 'EASTPORT-SOUTH MANOR CSD'
#  'FISHERS ISLAND UNION FREE SCHOOL DISTRICT'
#  'SOUTHOLD UNION FREE SCHOOL DISTRICT'
#  'GREENPORT UNION FREE SCHOOL DISTRICT'
#  'MATTITUCK-CUTCHOGUE UNION FREE SCHOOL DISTRICT'
#  'FALLSBURG CENTRAL SCHOOL DISTRICT' 'ELDRED CENTRAL SCHOOL DISTRICT'
#  'LIBERTY CENTRAL SCHOOL DISTRICT' 'TRI-VALLEY CENTRAL SCHOOL DISTRICT'
#  'ROSCOE CENTRAL SCHOOL DISTRICT'
#  'LIVINGSTON MANOR CENTRAL SCHOOL DISTRICT'
#  'MONTICELLO CENTRAL SCHOOL DISTRICT'
#  'SULLIVAN WEST CENTRAL SCHOOL DISTRICT' 'WAVERLY CENTRAL SCHOOL DISTRICT'
#  'CANDOR CENTRAL SCHOOL DISTRICT' 'NEWARK VALLEY CENTRAL SCHOOL DISTRICT'
#  'OWEGO-APALACHIN CENTRAL SCHOOL DISTRICT'
#  'SPENCER-VAN ETTEN CENTRAL SCHOOL DISTRICT'
#  'TIOGA CENTRAL SCHOOL DISTRICT' 'DRYDEN CENTRAL SCHOOL DISTRICT'
#  'GEORGE JUNIOR REPUBLIC UNION FREE SCHOOL DISTRICT'
#  'GROTON CENTRAL SCHOOL DISTRICT' 'ITHACA CITY SCHOOL DISTRICT'
#  'LANSING CENTRAL SCHOOL DISTRICT' 'NEWFIELD CENTRAL SCHOOL DISTRICT'
#  'TRUMANSBURG CENTRAL SCHOOL DISTRICT' 'KINGSTON CITY SCHOOL DISTRICT'
#  'HIGHLAND CENTRAL SCHOOL DISTRICT'
#  'RONDOUT VALLEY CENTRAL SCHOOL DISTRICT'
#  'MARLBORO CENTRAL SCHOOL DISTRICT' 'NEW PALTZ CENTRAL SCHOOL DISTRICT'
#  'ONTEORA CENTRAL SCHOOL DISTRICT' 'SAUGERTIES CENTRAL SCHOOL DISTRICT'
#  'WALLKILL CENTRAL SCHOOL DISTRICT' 'ELLENVILLE CENTRAL SCHOOL DISTRICT'
#  'BOLTON CENTRAL SCHOOL DISTRICT' 'NORTH WARREN CENTRAL SCHOOL DISTRICT'
#  'GLENS FALLS CITY SCHOOL DISTRICT' 'JOHNSBURG CENTRAL SCHOOL DISTRICT'
#  'LAKE GEORGE CENTRAL SCHOOL DISTRICT'
#  'HADLEY-LUZERNE CENTRAL SCHOOL DISTRICT'
#  'QUEENSBURY UNION FREE SCHOOL DISTRICT'
#  'WARRENSBURG CENTRAL SCHOOL DISTRICT' 'ARGYLE CENTRAL SCHOOL DISTRICT'
#  'FORT ANN CENTRAL SCHOOL DISTRICT'
#  'FORT EDWARD UNION FREE SCHOOL DISTRICT'
#  'GRANVILLE CENTRAL SCHOOL DISTRICT' 'GREENWICH CENTRAL SCHOOL DISTRICT'
#  'HARTFORD CENTRAL SCHOOL DISTRICT' 'HUDSON FALLS CENTRAL SCHOOL DISTRICT'
#  'SALEM CENTRAL SCHOOL DISTRICT' 'CAMBRIDGE CENTRAL SCHOOL DISTRICT'
#  'WHITEHALL CENTRAL SCHOOL DISTRICT' 'NEWARK CENTRAL SCHOOL DISTRICT'
#  'CLYDE-SAVANNAH CENTRAL SCHOOL DISTRICT' 'LYONS CENTRAL SCHOOL DISTRICT'
#  'MARION CENTRAL SCHOOL DISTRICT' 'WAYNE CENTRAL SCHOOL DISTRICT'
#  'PALMYRA-MACEDON CENTRAL SCHOOL DISTRICT'
#  'GANANDA CENTRAL SCHOOL DISTRICT' 'SODUS CENTRAL SCHOOL DISTRICT'
#  'WILLIAMSON CENTRAL SCHOOL DISTRICT'
#  'NORTH ROSE-WOLCOTT CENTRAL SCHOOL DISTRICT'
#  'RED CREEK CENTRAL SCHOOL DISTRICT'
#  'KATONAH-LEWISBORO UNION FREE SCHOOL DISTRICT'
#  'BEDFORD CENTRAL SCHOOL DISTRICT'
#  'CROTON-HARMON UNION FREE SCHOOL DISTRICT'
#  'HENDRICK HUDSON CENTRAL SCHOOL DISTRICT'
#  'EASTCHESTER UNION FREE SCHOOL DISTRICT'
#  'TUCKAHOE UNION FREE SCHOOL DISTRICT'
#  'BRONXVILLE UNION FREE SCHOOL DISTRICT'
#  'UNION FREE SCHOOL DISTRICT OF THE TARRYTOWNS'
#  'IRVINGTON UNION FREE SCHOOL DISTRICT'
#  'DOBBS FERRY UNION FREE SCHOOL DISTRICT'
#  'HASTINGS-ON-HUDSON UNION FREE SCHOOL DISTRICT'
#  'ARDSLEY UNION FREE SCHOOL DISTRICT'
#  'EDGEMONT UNION FREE SCHOOL DISTRICT'
#  'GREENBURGH CENTRAL SCHOOL DISTRICT'
#  'ELMSFORD UNION FREE SCHOOL DISTRICT'
#  'GREENBURGH-GRAHAM UNION FREE SCHOOL DISTRICT'
#  'GREENBURGH ELEVEN UNION FREE SCHOOL DISTRICT'
#  'GREENBURGH-NORTH CASTLE UNION FREE SCHOOL DISTRICT'
#  'HARRISON CENTRAL SCHOOL DISTRICT'
#  'MAMARONECK UNION FREE SCHOOL DISTRICT'
#  'MOUNT PLEASANT CENTRAL SCHOOL DISTRICT'
#  'HAWTHORNE-CEDAR KNOLLS UNION FREE SCHOOL DISTRICT'
#  'MOUNT PLEASANT-COTTAGE UNION FREE SCHOOL DISTRICT'
#  'VALHALLA UNION FREE SCHOOL DISTRICT'
#  'PLEASANTVILLE UNION FREE SCHOOL DISTRICT' 'MOUNT VERNON SCHOOL DISTRICT'
#  'CHAPPAQUA CENTRAL SCHOOL DISTRICT' 'NEW ROCHELLE CITY SCHOOL DISTRICT'
#  'BYRAM HILLS CENTRAL SCHOOL DISTRICT'
#  'NORTH SALEM CENTRAL SCHOOL DISTRICT'
#  'OSSINING UNION FREE SCHOOL DISTRICT'
#  'BRIARCLIFF MANOR UNION FREE SCHOOL DISTRICT'
#  'PEEKSKILL CITY SCHOOL DISTRICT' 'PELHAM UNION FREE SCHOOL DISTRICT'
#  'RYE CITY SCHOOL DISTRICT' 'RYE NECK UNION FREE SCHOOL DISTRICT'
#  'PORT CHESTER-RYE UNION FREE SCHOOL DISTRICT'
#  'BLIND BROOK-RYE UNION FREE SCHOOL DISTRICT'
#  'SCARSDALE UNION FREE SCHOOL DISTRICT' 'SOMERS CENTRAL SCHOOL DISTRICT'
#  'WHITE PLAINS CITY SCHOOL DISTRICT' 'YONKERS CITY SCHOOL DISTRICT'
#  'LAKELAND CENTRAL SCHOOL DISTRICT' 'YORKTOWN CENTRAL SCHOOL DISTRICT'
#  'ATTICA CENTRAL SCHOOL DISTRICT' 'LETCHWORTH CENTRAL SCHOOL DISTRICT'
#  'PERRY CENTRAL SCHOOL DISTRICT' 'WARSAW CENTRAL SCHOOL DISTRICT'
#  'PENN YAN CENTRAL SCHOOL DISTRICT' 'DUNDEE CENTRAL SCHOOL DISTRICT']

# %%
len(unique_values)
# Out:
# 677
